# %% [markdown]
# <a href="https://colab.research.google.com/github/2017soft/MovieReview/blob/master/transformer_bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp 'drive/My Drive/utils.py' .

# %%
from utils import read_data_csv

# %%
df = read_data_csv('dataset.csv')
print(df.head())
# Out:
#                                               REVIEW  SENTIMENT
# 0  A series of escapades demonstrating the adage ...          1
# 1  A series of escapades demonstrating the adage ...          2
# 2                                           A series          2
# 3                                                  A          2
# 4                                             series          2

# %%
# !pip install transformers
import torch
import transformers
from torch.utils.data import Dataset, DataLoader
from transformers import BertModel, BertTokenizer
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/50/0c/7d5950fcd80b029be0a8891727ba21e0cd27692c407c51261c3c921f6da3/transformers-4.1.1-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 11.7MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.19.4)
# Collecting tokenizers==0.9.4
#   Downloading https://files.pythonhosted.org/packages/0f/1c/e789a8b12e28be5bc1ce2156cf87cb522b379be9cadc7ad8091a4cc107c4/tokenizers-0.9.4-cp36-cp36m-manylinux2010_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 48.4MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 50.4MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.0.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=73ef46de419479ddcda0482170d81a4ed44a452a1147ea93aa3483d27ac556e2
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.9.4 transformers-4.1.1

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Define some hyperparameters

# %%
MAX_LEN = 64
TRAIN_BATCH_SIZE = 100
VALID_BATCH_SIZE = 100
EPOCHS = 10
LEARNING_RATE = 1e-05
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=213450.0, style=ProgressStyle(descripti…

# %% [markdown]
# # Preprocess the text data

# %%
class Triage(Dataset):
    def __init__(self, dataframe, tokenizer, max_len):
        self.len = len(dataframe)
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_len = max_len
        
    def __getitem__(self, index):
        review = str(self.data.REVIEW[index])
        review = " ".join(review.split())
        inputs = self.tokenizer.encode_plus(
            review,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            pad_to_max_length=True,
            return_token_type_ids=True,
            truncation=True
        )
        ids = inputs['input_ids']
        mask = inputs['attention_mask']

        return {
            'ids': torch.tensor(ids, dtype=torch.long),
            'mask': torch.tensor(mask, dtype=torch.long),
            'targets': torch.tensor(self.data.SENTIMENT[index], dtype=torch.long)
        } 
    
    def __len__(self):
        return self.len

# %%
random_seed = 0
train_size = 0.95
train_dataset=df.sample(frac=train_size,random_state=random_seed)
test_dataset=df.drop(train_dataset.index).reset_index(drop=True)
train_dataset = train_dataset.reset_index(drop=True)

print("FULL Dataset: {}".format(df.shape))
print("TRAIN Dataset: {}".format(train_dataset.shape))
print("TEST Dataset: {}".format(test_dataset.shape))

training_set = Triage(train_dataset, tokenizer, MAX_LEN)
testing_set = Triage(test_dataset, tokenizer, MAX_LEN)
# Out:
# FULL Dataset: (156060, 2)
# TRAIN Dataset: (148257, 2)
# TEST Dataset: (7803, 2)

# %%
train_params = {'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

test_params = {'batch_size': VALID_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

training_loader = DataLoader(training_set, **train_params)
testing_loader = DataLoader(testing_set, **test_params)

# %% [markdown]
# # Define the modified BERT model for this sentiment classification task

# %%
class BERTClass(torch.nn.Module):
    def __init__(self):
        super(BERTClass, self).__init__()
        self.l1 = BertModel.from_pretrained("bert-base-uncased")
        self.pre_classifier = torch.nn.Linear(768, 768)
        self.dropout = torch.nn.Dropout(0.3)
        self.classifier = torch.nn.Linear(768, 5)

    def forward(self, input_ids, attention_mask):
        output_1 = self.l1(input_ids=input_ids, attention_mask=attention_mask)
        hidden_state = output_1[0]
        pooler = hidden_state[:, 0]
        pooler = self.pre_classifier(pooler)
        pooler = torch.nn.ReLU()(pooler)
        pooler = self.dropout(pooler)
        output = self.classifier(pooler)
        return output

# %%
model = BERTClass()
model.to(device)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…
# BERTClass(
#   (l1): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (classifier): Linear(in_features=768, out_features=5, bias=True)
# )

# %% [markdown]
# # Create the loss function and the optimizer

# %%
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params =  model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# # Import the training and validation function for tuning the model

# %%
from utils import train, valid

# %%
from datetime import datetime

# %%
for epoch in range(EPOCHS):
  train(model, training_loader, loss_function, optimizer, epoch, device, report_steps=200)
  valid(model, testing_loader, loss_function, epoch, device, report_steps=20)
  if epoch % 3 == 0:
    torch.save(model.state_dict(), f"drive/My Drive/my_bert_model_{datetime.now()}.pt")
# Out:
# There are 1483 batches in the training set
# /usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils_base.py:2179: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Training Loss after step 0: 1.6711827516555786
# Training Accuracy after step 0: 14.0
# Training Loss after step 200: 1.2587491683105925
# Training Accuracy after step 200: 49.60696517412935
# Training Loss after step 400: 1.2309422665403371
# Training Accuracy after step 400: 50.44887780548628
# Training Loss after step 600: 1.2190131068031325
# Training Accuracy after step 600: 50.99001663893511
# Training Loss after step 800: 1.2094431297014119
# Training Accuracy after step 800: 51.1398252184769
# Training Loss after step 1000: 1.197708324893014
# Training Accuracy after step 1000: 51.57142857142857
# Training Loss after step 1200: 1.182866516061667
# Training Accuracy after step 1200: 52.210657785179016
# Training Loss after step 1400: 1.1662412259427246
# Training Accuracy after step 1400: 52.91720199857245
# The Total Accuracy for Epoch 0: 53.15769238551974
# Training Loss Epoch 0: 1.159979079835574
# Training Accuracy Epoch 0: 53.15769238551974
# There are 79 batches in the test set
# Validation Loss after 0 steps: 0.9664863348007202
# Validation Accuracy after 0 steps: 64.0
# Validation Loss after 20 steps: 0.9735686211358934
# Validation Accuracy after 20 steps: 62.38095238095238
# Validation Loss after 40 steps: 0.9873805293222753
# Validation Accuracy after 40 steps: 61.19512195121951
# Validation Loss after 60 steps: 0.9926453799497886
# Validation Accuracy after 60 steps: 60.885245901639344
# Validation Loss after Epoch 0: 0.9969630143310451
# Validation Accuracy after Epoch 0: 60.47673971549404
# There are 1483 batches in the training set
# Training Loss after step 0: 1.0012859106063843
# Training Accuracy after step 0: 61.0
# Training Loss after step 200: 1.0032855485802266
# Training Accuracy after step 200: 59.60696517412935
# Training Loss after step 400: 0.9936899291606912
# Training Accuracy after step 400: 59.917705735660846
# Training Loss after step 600: 0.9844568343011789
# Training Accuracy after step 600: 60.2279534109817
# Training Loss after step 800: 0.9750140870406238
# Training Accuracy after step 800: 60.48938826466917
# Training Loss after step 1000: 0.9663072558907004
# Training Accuracy after step 1000: 60.75124875124875
# Training Loss after step 1200: 0.9594436194577086
# Training Accuracy after step 1200: 60.99000832639467
# Training Loss after step 1400: 0.9533765341110693
# Training Accuracy after step 1400: 61.194860813704494
# The Total Accuracy for Epoch 1: 61.2962625710759
# Training Loss Epoch 1: 0.9505468252054036
# Training Accuracy Epoch 1: 61.2962625710759
# There are 79 batches in the test set
# Validation Loss after 0 steps: 0.899580180644989
# Validation Accuracy after 0 steps: 59.0
# Validation Loss after 20 steps: 0.8856761455535889
# Validation Accuracy after 20 steps: 63.333333333333336
# Validation Loss after 40 steps: 0.8862697147741551
# Validation Accuracy after 40 steps: 63.24390243902439
# Validation Loss after 60 steps: 0.8812289921963801
# Validation Accuracy after 60 steps: 63.67213114754098
# Validation Loss after Epoch 1: 0.8838827240316174
# Validation Accuracy after Epoch 1: 63.62937331795463
# There are 1483 batches in the training set
# Training Loss after step 0: 0.7355738282203674
# Training Accuracy after step 0: 72.0
# Training Loss after step 200: 0.8462890078179279
# Training Accuracy after step 200: 65.58208955223881
# Training Loss after step 400: 0.8461278162692253
# Training Accuracy after step 400: 65.56608478802993
# Training Loss after step 600: 0.8444645766807277
# Training Accuracy after step 600: 65.58236272878536
# Training Loss after step 800: 0.8428739746858118
# Training Accuracy after step 800: 65.65168539325843
# Training Loss after step 1000: 0.8385804407484644
# Training Accuracy after step 1000: 65.83916083916084
# Training Loss after step 1200: 0.8358200404368075
# Training Accuracy after step 1200: 65.90008326394671
# Training Loss after step 1400: 0.8331776693154879
# Training Accuracy after step 1400: 66.02640970735189
# The Total Accuracy for Epoch 2: 66.08726738029233
# Training Loss Epoch 2: 0.8318373093875131
# Training Accuracy Epoch 2: 66.08726738029233
# There are 79 batches in the test set
# Validation Loss after 0 steps: 0.7989491820335388
# Validation Accuracy after 0 steps: 63.0
# Validation Loss after 20 steps: 0.8596095556304568
# Validation Accuracy after 20 steps: 65.85714285714286
# Validation Loss after 40 steps: 0.8543384540371779
# Validation Accuracy after 40 steps: 65.60975609756098
# Validation Loss after 60 steps: 0.843874348968756
# Validation Accuracy after 60 steps: 65.65573770491804
# Validation Loss after Epoch 2: 0.8427751098252549
# Validation Accuracy after Epoch 2: 65.52607971293092
# There are 1483 batches in the training set
# Training Loss after step 0: 0.7002678513526917
# Training Accuracy after step 0: 72.0
# Training Loss after step 200: 0.7582702319420392
# Training Accuracy after step 200: 68.94029850746269
# Training Loss after step 400: 0.7589034027886807
# Training Accuracy after step 400: 68.91271820448878
# Training Loss after step 600: 0.7625121775760428
# Training Accuracy after step 600: 68.85024958402663
# Training Loss after step 800: 0.7631906756896354
# Training Accuracy after step 800: 68.82771535580524
# Training Loss after step 1000: 0.763218671172768
# Training Accuracy after step 1000: 68.77222777222777
# Training Loss after step 1200: 0.7628918088147484
# Training Accuracy after step 1200: 68.81099084096586
# Training Loss after step 1400: 0.7624059396926886
# Training Accuracy after step 1400: 68.90078515346181
# The Total Accuracy for Epoch 3: 68.8520609482183
# Training Loss Epoch 3: 0.7624288162747831
# Training Accuracy Epoch 3: 68.8520609482183
# There are 79 batches in the test set
# Validation Loss after 0 steps: 0.9618037343025208
# Validation Accuracy after 0 steps: 64.0
# Validation Loss after 20 steps: 0.8269150540942237
# Validation Accuracy after 20 steps: 67.38095238095238
# Validation Loss after 40 steps: 0.8236595043321935
# Validation Accuracy after 40 steps: 66.82926829268293
# Validation Loss after 60 steps: 0.8233766526472374
# Validation Accuracy after 60 steps: 66.8688524590164
# Validation Loss after Epoch 3: 0.814193790849251
# Validation Accuracy after Epoch 3: 66.92297834166347
# There are 1483 batches in the training set
# Training Loss after step 0: 0.7073268294334412
# Training Accuracy after step 0: 69.0
# Training Loss after step 200: 0.7113976626846921
# Training Accuracy after step 200: 70.98009950248756
# Training Loss after step 400: 0.7118293205996107
# Training Accuracy after step 400: 71.0
# Training Loss after step 600: 0.709964011651704
# Training Accuracy after step 600: 71.01497504159734
# Training Loss after step 800: 0.7092129577709345
# Training Accuracy after step 800: 71.08988764044943
# Training Loss after step 1000: 0.709271740186941
# Training Accuracy after step 1000: 71.15184815184816
# Training Loss after step 1200: 0.711565872810961
# Training Accuracy after step 1200: 71.04329725228976
# Training Loss after step 1400: 0.7120136552244999
# Training Accuracy after step 1400: 70.94432548179871
# The Total Accuracy for Epoch 4: 70.93830308181064
# Training Loss Epoch 4: 0.7122283639010752
# Training Accuracy Epoch 4: 70.93830308181064
# There are 79 batches in the test set
# Validation Loss after 0 steps: 0.8483380079269409
# Validation Accuracy after 0 steps: 64.0
# Validation Loss after 20 steps: 0.8193523940585908
# Validation Accuracy after 20 steps: 67.52380952380952
# Validation Loss after 40 steps: 0.8218100289019142
# Validation Accuracy after 40 steps: 67.5609756097561
# Validation Loss after 60 steps: 0.803744526183019
# Validation Accuracy after 60 steps: 68.34426229508196
# Validation Loss after Epoch 4: 0.799428630856019
# Validation Accuracy after Epoch 4: 68.39677047289504
# There are 1483 batches in the training set
# Training Loss after step 0: 0.5656378269195557
# Training Accuracy after step 0: 80.0
# Training Loss after step 200: 0.6536011211018065
# Training Accuracy after step 200: 73.11940298507463
# Training Loss after step 400: 0.6563821420110669
# Training Accuracy after step 400: 73.16209476309227
# Training Loss after step 600: 0.6588530656006094
# Training Accuracy after step 600: 73.0648918469218
# Training Loss after step 800: 0.6640553676829059
# Training Accuracy after step 800: 72.87640449438203
# Training Loss after step 1000: 0.668042535459126
# Training Accuracy after step 1000: 72.65234765234766
# Training Loss after step 1200: 0.6696431530107566
# Training Accuracy after step 1200: 72.53372189841798
# Training Loss after step 1400: 0.6697299927153986
# Training Accuracy after step 1400: 72.46395431834404
# The Total Accuracy for Epoch 5: 72.45323998192328
# Training Loss Epoch 5: 0.670135260190983
# Training Accuracy Epoch 5: 72.45323998192328
# There are 79 batches in the test set
# Validation Loss after 0 steps: 0.8474120497703552
# Validation Accuracy after 0 steps: 70.0
# Validation Loss after 20 steps: 0.8030119765372503
# Validation Accuracy after 20 steps: 68.71428571428571
# Validation Loss after 40 steps: 0.8048513226392793
# Validation Accuracy after 40 steps: 67.73170731707317
# Validation Loss after 60 steps: 0.81735224997411
# Validation Accuracy after 60 steps: 67.47540983606558
# Validation Loss after Epoch 5: 0.8142638285703296
# Validation Accuracy after Epoch 5: 67.55094194540561
# There are 1483 batches in the training set
# Training Loss after step 0: 0.6038928627967834
# Training Accuracy after step 0: 74.0
# Training Loss after step 200: 0.6143694207146393
# Training Accuracy after step 200: 74.82587064676616
# Training Loss after step 400: 0.621633767115505
# Training Accuracy after step 400: 74.68329177057356
# Training Loss after step 600: 0.6251604225294364
# Training Accuracy after step 600: 74.47254575707154
# Training Loss after step 800: 0.625320416525211
# Training Accuracy after step 800: 74.38202247191012
# Training Loss after step 1000: 0.6272630724278125
# Training Accuracy after step 1000: 74.26073926073926
# Training Loss after step 1200: 0.6285060699734462
# Training Accuracy after step 1200: 74.21315570358036
# Training Loss after step 1400: 0.6321034269363518
# Training Accuracy after step 1400: 74.06281227694504
# The Total Accuracy for Epoch 6: 73.9695258908517
# Training Loss Epoch 6: 0.6331715414191289
# Training Accuracy Epoch 6: 73.9695258908517
# There are 79 batches in the test set
# Validation Loss after 0 steps: 0.7505533695220947
# Validation Accuracy after 0 steps: 62.0
# Validation Loss after 20 steps: 0.8594256440798441
# Validation Accuracy after 20 steps: 65.95238095238095
# Validation Loss after 40 steps: 0.8418545926489481
# Validation Accuracy after 40 steps: 66.07317073170732
# Validation Loss after 60 steps: 0.8416617913324325
# Validation Accuracy after 60 steps: 66.21311475409836
# Validation Loss after Epoch 6: 0.8363038723981833
# Validation Accuracy after Epoch 6: 66.53851082916827
# There are 1483 batches in the training set
# Training Loss after step 0: 0.6520124673843384
# Training Accuracy after step 0: 73.0
# Training Loss after step 200: 0.5855913872445994
# Training Accuracy after step 200: 76.0
# Training Loss after step 400: 0.5947361178974856
# Training Accuracy after step 400: 75.75561097256858
# Training Loss after step 600: 0.5965735164041726
# Training Accuracy after step 600: 75.67720465890183
# Training Loss after step 800: 0.599961139438453
# Training Accuracy after step 800: 75.51935081148564
# Training Loss after step 1000: 0.601335024142956
# Training Accuracy after step 1000: 75.42057942057941
# Training Loss after step 1200: 0.6015544165232894
# Training Accuracy after step 1200: 75.41382181515404
# Training Loss after step 1400: 0.6040027881842864
# Training Accuracy after step 1400: 75.24768022840829
# The Total Accuracy for Epoch 7: 75.27806444215113
# Training Loss Epoch 7: 0.6036589992705504
# Training Accuracy Epoch 7: 75.27806444215113
# There are 79 batches in the test set
# Validation Loss after 0 steps: 0.8856967091560364
# Validation Accuracy after 0 steps: 64.0
# Validation Loss after 20 steps: 0.8710375882330395
# Validation Accuracy after 20 steps: 67.14285714285714
# Validation Loss after 40 steps: 0.8577183921162675
# Validation Accuracy after 40 steps: 66.70731707317073
# Validation Loss after 60 steps: 0.8589877290803878
# Validation Accuracy after 60 steps: 66.70491803278688
# Validation Loss after Epoch 7: 0.8761314055587672
# Validation Accuracy after Epoch 7: 66.89734717416378
# There are 1483 batches in the training set
# Training Loss after step 0: 0.5521702170372009
# Training Accuracy after step 0: 80.0
# Training Loss after step 200: 0.5464648057275744
# Training Accuracy after step 200: 77.34328358208955
# Training Loss after step 400: 0.5520993138935203
# Training Accuracy after step 400: 77.17955112219451
# Training Loss after step 600: 0.558066206595267
# Training Accuracy after step 600: 77.01497504159734
# Training Loss after step 800: 0.5605026054918096
# Training Accuracy after step 800: 76.93632958801498
# Training Loss after step 1000: 0.5656435948747259
# Training Accuracy after step 1000: 76.75124875124875
# Training Loss after step 1200: 0.5690416842078686
# Training Accuracy after step 1200: 76.6278101582015
# Training Loss after step 1400: 0.5703042714320107
# Training Accuracy after step 1400: 76.56673804425411
# The Total Accuracy for Epoch 8: 76.50431345568843
# Training Loss Epoch 8: 0.5715723160104179
# Training Accuracy Epoch 8: 76.50431345568843
# There are 79 batches in the test set
# Validation Loss after 0 steps: 0.8842479586601257
# Validation Accuracy after 0 steps: 66.0
# Validation Loss after 20 steps: 0.8793885594322568
# Validation Accuracy after 20 steps: 65.61904761904762
# Validation Loss after 40 steps: 0.8734234469692882
# Validation Accuracy after 40 steps: 66.0
# Validation Loss after 60 steps: 0.8701539274121894
# Validation Accuracy after 60 steps: 65.85245901639344
# Validation Loss after Epoch 8: 0.8613909482955933
# Validation Accuracy after Epoch 8: 66.0643342304242
# There are 1483 batches in the training set
# Training Loss after step 0: 0.49734652042388916
# Training Accuracy after step 0: 81.0
# Training Loss after step 200: 0.5256866516165473
# Training Accuracy after step 200: 78.636815920398
# Training Loss after step 400: 0.525162622815653
# Training Accuracy after step 400: 78.55610972568579
# Training Loss after step 600: 0.5303332379673563
# Training Accuracy after step 600: 78.28785357737105
# Training Loss after step 800: 0.5332862695727902
# Training Accuracy after step 800: 78.1023720349563
# Training Loss after step 1000: 0.537105820246867
# Training Accuracy after step 1000: 77.93306693306694
# Training Loss after step 1200: 0.5389770877351372
# Training Accuracy after step 1200: 77.86677768526228
# Training Loss after step 1400: 0.541345284037893
# Training Accuracy after step 1400: 77.78372591006423
# The Total Accuracy for Epoch 9: 77.71909589429167
# Training Loss Epoch 9: 0.5422088641294015
# Training Accuracy Epoch 9: 77.71909589429167
# There are 79 batches in the test set
# Validation Loss after 0 steps: 1.0750788450241089
# Validation Accuracy after 0 steps: 60.0
# Validation Loss after 20 steps: 0.8902896898133414
# Validation Accuracy after 20 steps: 66.38095238095238
# Validation Loss after 40 steps: 0.9204834801394765
# Validation Accuracy after 40 steps: 65.95121951219512
# Validation Loss after 60 steps: 0.9217460898102307
# Validation Accuracy after 60 steps: 65.9672131147541
# Validation Loss after Epoch 9: 0.9047253207315372
# Validation Accuracy after Epoch 9: 66.37190824042035

# %% [markdown]
# ### Part of the code in this notebook is modified from the tutorial here https://github.com/abhimishra91/transformers-tutorials/blob/master/transformers_multiclass_classification.ipynb
